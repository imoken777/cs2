# %%
import matplotlib.pyplot as plt
import math

xs = [i * 0.1 for i in range(-100, 101)]

ys = [math.sin(x) for x in xs]

plt.plot(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y=sin(x)")
plt.show()
